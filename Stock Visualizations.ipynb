# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns


# Mount Google Drive if not already mounted
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
directory_path = '/content/drive/MyDrive/CS418_Project/data'
# Read CSV files into DataFrames
data_2020 = pd.DataFrame(pd.read_csv(directory_path + '/rank_name_symbol_2020.csv'))
data_2021 = pd.DataFrame(pd.read_csv(directory_path + '/rank_name_symbol_2021.csv'))
data_2022 = pd.DataFrame(pd.read_csv(directory_path + '/rank_name_symbol_2022.csv'))
data_2023 = pd.DataFrame(pd.read_csv(directory_path + '/rank_name_symbol_2023.csv'))

# %%
# Cleaning the data for the missing value
# Drop rows where any of the specified columns have null values
data_2020_cleaned = data_2020.dropna()
data_2021_cleaned = data_2021.dropna()
data_2022_cleaned = data_2022.dropna()
data_2023_cleaned = data_2023.dropna()

# %%
# Remove commas from the 'Profit' column
data_2020_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')
data_2021_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')
data_2022_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')
data_2023_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')

# Convert the 'Profit' column to float
data_2020_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)
data_2021_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)
data_2022_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)
data_2023_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)

# Remove commas from the 'Revenue' column
data_2020_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')
data_2021_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')
data_2022_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')
data_2023_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')

# Convert the 'Revenue' column to float
data_2020_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)
data_2021_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)
data_2022_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)
data_2023_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)


# Convert the Stocks columns to float
data_2020_cleaned.loc[:, 'm1-o':'m12-c'] = data_2020_cleaned.loc[:, 'm1-o':'m12-c'].astype(float)
data_2021_cleaned.loc[:, 'm1-o':'m12-c'] = data_2021_cleaned.loc[:, 'm1-o':'m12-c'].astype(float)
data_2022_cleaned.loc[:, 'm1-o':'m12-c'] = data_2022_cleaned.loc[:, 'm1-o':'m12-c'].astype(float)
data_2023_cleaned.loc[:, 'm1-o':'m12-c'] = data_2023_cleaned.loc[:, 'm1-o':'m12-c'].astype(float)


# Convert the columns of string type
data_2020_cleaned.loc[:, 'Name':'Industry'] = data_2020_cleaned.loc[:, 'Name':'Industry'].astype(str)
data_2021_cleaned.loc[:, 'Name':'Industry'] = data_2021_cleaned.loc[:, 'Name':'Industry'].astype(str)
data_2022_cleaned.loc[:, 'Name':'Industry'] = data_2022_cleaned.loc[:, 'Name':'Industry'].astype(str)
data_2023_cleaned.loc[:, 'Name':'Industry'] = data_2023_cleaned.loc[:, 'Name':'Industry'].astype(str)

data_2020_cleaned
# Out:
# <ipython-input-5-41a262f96bd2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2021_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2022_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2023_cleaned['Profit'] = data_2020_cleaned['Profit'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)
# <ipython-input-5-41a262f96bd2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2021_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)
# <ipython-input-5-41a262f96bd2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2022_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)
# <ipython-input-5-41a262f96bd2>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2023_cleaned['Profit'] = data_2020_cleaned['Profit'].astype(float)
# <ipython-input-5-41a262f96bd2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2021_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2022_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2023_cleaned['Revenue'] = data_2020_cleaned['Revenue'].str.replace(',', '')
# <ipython-input-5-41a262f96bd2>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)
# <ipython-input-5-41a262f96bd2>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2021_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)
# <ipython-input-5-41a262f96bd2>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2022_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)
# <ipython-input-5-41a262f96bd2>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2023_cleaned['Revenue'] = data_2020_cleaned['Revenue'].astype(float)
#      Rank                        Name Ticker              Sector  \
# 0       1                     Walmart    WMT  Consumer Defensive
# 1       2                  Amazon.com   AMZN   Consumer Cyclical
# 2       3                 Exxon Mobil    XOM              Energy
# 3       4                       Apple   AAPL          Technology
# 4       5                  CVS Health    CVS          Healthcare
# ..    ...                         ...    ...                 ...
# 494   495                Levi Strauss   LEVI   Consumer Cyclical
# 495   496  Crown Castle International    CCI         Real Estate
# 496   497        Simon Property Group    SPG         Real Estate
# 498   499               Post Holdings   POST  Consumer Defensive
# 499   500       Huntington Bancshares   HBAN  Financial Services
#
#                   Industry   Revenue   Profit    m1-o      m1-c     m2-o  ...  \
# 0          Discount Stores  523964.0  14881.0   39.62   38.1633   38.300  ...
# 1          Internet Retail  280522.0  11588.0   93.75  100.4360  100.530  ...
# 2     Oil & Gas Integrated  264938.0  14340.0   70.24   62.1200   61.380  ...
# 3     Consumer Electronics  260174.0  55256.0   74.06   77.3775   76.075  ...
# 4         Healthcare Plans  256776.0   6634.0   74.65   67.8200   68.400  ...
# ..                     ...       ...      ...     ...       ...      ...  ...
# 494  Apparel Manufacturing    5763.1    394.6   19.33   19.6400   18.610  ...
# 495       REIT - Specialty    5763.0    860.0  142.33  149.8400  150.680  ...
# 496          REIT - Retail    5755.2   2101.6  149.41  133.1500  133.380  ...
# 498         Packaged Foods    5681.1    124.7  109.24  104.5700  105.190  ...
# 499       Banks - Regional    5655.0   1411.0   15.12   13.5700   13.700  ...
#
#          m8-o      m8-c      m9-o      m9-c     m10-o     m10-c     m11-o  \
# 0     43.3033   46.2833   47.0667   46.6367   46.9333   46.2500   46.8633
# 1    159.0255  172.5480  174.4790  157.4365  160.4000  151.8075  153.0870
# 2     42.0500   39.9400   39.7500   34.3300   33.7900   32.6200   33.1400
# 3    108.2000  129.0400  132.7600  115.8100  117.6400  108.8600  109.1100
# 4     63.4500   62.1200   62.0100   58.4000   58.4300   56.0900   56.8700
# ..        ...       ...       ...       ...       ...       ...       ...
# 494   12.1800   12.3200   12.3000   13.4000   13.6400   15.7800   15.9900
# 495  165.9300  163.2500  162.5100  166.5000  166.7500  156.2000  157.4500
# 496   61.2100   67.8500   66.6500   64.6800   64.8400   62.8100   62.9600
# 498   89.1400   88.0200   87.6500   86.0000   86.3000   85.9000   86.9200
# 499    9.3700    9.4100    9.3100    9.1700    9.2900   10.4400   10.6000
#
#        m11-c    m12-o     m12-c
# 0     50.930   51.200   48.0500
# 1    158.402  159.425  162.8465
# 2     38.130   38.960   41.2200
# 3    119.050  121.010  132.6900
# 4     67.790   68.390   68.3000
# ..       ...      ...       ...
# 494   18.390   18.710   20.0800
# 495  167.570  168.000  159.1900
# 496   82.570   84.650   85.2800
# 498   94.460   95.430  101.0100
# 499   12.080   12.510   12.6300
#
# [425 rows x 31 columns]

# %%
#Some sort of standardization like this is likely to be used in the ML Analysis

# from sklearn.preprocessing import StandardScaler



# # Define categorical and numerical column names
# numerical_cols = ['Revenue',	'Profit',	'm1-o',	'm1-c',	'm2-o', 'm2-c', 'm3-o', 'm3-c', 'm4-o', 'm4-c', 'm5-o', 'm5-c', 'm6-o', 'm6-c', 'm7-o', 'm7-c', 'm8-o',	'm8-c','m9-o',	'm9-c',	'm10-o',	'm10-c',	'm11-o',	'm11-c',	'm12-o',	'm12-c']
# categorical_cols = ['Rank', 'Name', 'Ticker', 'Sector', 'Industry']

# # Initialize StandardScaler for numerical columns
# numerical_transformer = StandardScaler()

# # # Initialize ColumnTransformer
# # preprocessor = ColumnTransformer(
# #     transformers=[
# #         ('num', numerical_transformer, numerical_cols)
# #     ],
# #     remainder='passthrough'  # Keep the rest of the columns unchanged
# # )

# # Fit and transform the data
# transformed_data20 = numerical_transformer.fit_transform(data_2020_cleaned[numerical_cols])
# transformed_data21 = numerical_transformer.fit_transform(data_2021_cleaned[numerical_cols])
# transformed_data22 = numerical_transformer.fit_transform(data_2022_cleaned[numerical_cols])
# transformed_data23 = numerical_transformer.fit_transform(data_2023_cleaned[numerical_cols])

# # Convert the transformed data back to a DataFrame (optional)
# transformed_2020 = pd.DataFrame(transformed_data20, columns=numerical_cols)
# transformed_2021 = pd.DataFrame(transformed_data21, columns=numerical_cols)
# transformed_2022 = pd.DataFrame(transformed_data22, columns=numerical_cols)
# transformed_2023 = pd.DataFrame(transformed_data23, columns=numerical_cols)

# %%
tickers_of_interest = ['WMT', 'AMZN', 'AAPL', 'XOM', 'CVS']

df_subset_2020 = data_2020_cleaned[data_2020_cleaned['Ticker'].isin(tickers_of_interest)]
df_subset_2021 = data_2021_cleaned[data_2021_cleaned['Ticker'].isin(tickers_of_interest)]
df_subset_2022 = data_2022_cleaned[data_2022_cleaned['Ticker'].isin(tickers_of_interest)]
df_subset_2023 = data_2023_cleaned[data_2023_cleaned['Ticker'].isin(tickers_of_interest)]

df_combined = pd.concat([df_subset_2020, df_subset_2021, df_subset_2022, df_subset_2023])
df_combined = df_combined.drop(['Rank', 'Name', 'Sector', 'Industry', 'Revenue', 'Profit'], axis=1)

# %%
columns = ['Year', 'Month', 'Stock Open', 'Stock Close', 'Company']
empty_df = pd.DataFrame(columns=columns)
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
years = [2020, 2021, 2022, 2023]
company = list(df_combined['Ticker'])

j = 0
i = 0
for y in years:
  for c in range(5):
    for m in months:
      empty_df.at[j, 'Year'] = y
      empty_df.at[j, 'Month'] = m
      j+=1

open = True

for index, row in df_combined.iterrows():
  ro = 0
  comp = row['Ticker']
  for r in row:
    if ro>0:
      if open == True:
        open = False;
        empty_df.at[i, 'Stock Open'] = r
      else:
        open = True;
        empty_df.at[i, 'Stock Close'] = r
        empty_df.at[i, 'Company'] = comp
        i+=1
    ro+=1

# %%
plt = sns.pointplot(data=empty_df, x="Year", y='Stock Close', hue="Company")
plt.set_ylabel('Closing Stock Value')
plt.set_title('Stock Growth of Top Performing Fortune500 Companies 2020-2023')
legendObj = plt.legend(bbox_to_anchor=(1, -0.3, 1, 1), loc='upper left')#.set_loc("right"))
legendObj.set_title("Companies")
legendObj.set_frame_on(True)
handles, labels = legendObj.legendHandles, legendObj.texts
for t, label in zip(labels, ["Walmart", "Amazon", "Exxon Mobil", "Apple", "CVS Health"]):
    t.set_text(label)
# Out:
# <ipython-input-13-005c3eefb782>:7: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles, labels = legendObj.legendHandles, legendObj.texts
